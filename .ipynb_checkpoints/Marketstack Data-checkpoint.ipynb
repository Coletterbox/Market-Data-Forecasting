# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from api_key_container import api_key

# %%
url = "https://api.marketstack.com/v1/tickers?access_key=" + api_key
response = requests.get(url)
response_json = response.json()
print(response_json)
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 294935}, 'data': [{'name': 'Microsoft Corporation', 'symbol': 'MSFT', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Apple Inc', 'symbol': 'AAPL', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Amazon.com Inc', 'symbol': 'AMZN', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Alphabet Inc - Class C', 'symbol': 'GOOG', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Alphabet Inc - Class A', 'symbol': 'GOOGL', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Alibaba Group Holding Ltd', 'symbol': 'BABA', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'Meta Platforms Inc - Class A', 'symbol': 'FB', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'BERKSHIRE HATHAWAY INC', 'symbol': 'BRK.B', 'has_intraday': False, 'has_eod': False, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'BERKSHIRE HATHAWAY INC', 'symbol': 'BRK.A', 'has_intraday': False, 'has_eod': False, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'Vodafone Group plc', 'symbol': 'VOD', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'NASDAQ Stock Exchange', 'acronym': 'NASDAQ', 'mic': 'XNAS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nasdaq.com'}}, {'name': 'Visa Inc - Class A', 'symbol': 'V', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'JPMorgan Chase & Company', 'symbol': 'JPM', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'Johnson & Johnson', 'symbol': 'JNJ', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': 'USA', 'country_code': 'US', 'city': 'New York', 'website': 'www.nyse.com'}}, {'name': 'Walmart Inc', 'symbol': 'WMT', 'has_intraday': False, 'has_eod': True, 'country': None, 'stock_exchange': {'name': 'New York Stock Exchange', 'acronym': 'NYSE', 'mic': 'XNYS', 'country': ' ...

# %%
response_json
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 294935},
#  'data': [{'name': 'Microsoft Corporation',
#    'symbol': 'MSFT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Apple Inc',
#    'symbol': 'AAPL',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Amazon.com Inc',
#    'symbol': 'AMZN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Alphabet Inc - Class C',
#    'symbol': 'GOOG',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Alphabet Inc - Class A',
#    'symbol': 'GOOGL',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Alibaba Group Holding Ltd',
#    'symbol': 'BABA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Meta Platforms Inc - Class A',
#    'symbol': 'FB',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'BERKSHIRE HATHAWAY INC',
#    'symbol': 'BRK.B',
#    'has_intraday': False,
#    'has_eod': False,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'BERKSHIRE HATHAWAY INC',
#    'symbol': 'BRK.A',
#    'has_intraday': False,
#    'has_eod': False,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Vodafone Group plc',
#    'symbol': 'VOD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Visa Inc - Class A',
#    'symbol': 'V',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'JPMorgan Chase & Company',
#    'symbol': 'JPM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Johnson & Johnson',
#    'symbol': 'JNJ',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Walmart Inc',
#    'symbol': 'WMT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Mastercard Incorporated - Class A',
#    'symbol': 'MA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Procter & Gamble Company',
#    'symbol': 'PG',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Taiwan Semiconductor Manufacturing',
#    'symbol': 'TSM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Chunghwa Telecom',
#    'symbol': 'CHT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Roche Holding AG',
#    'symbol': 'RHHBF',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'OTC Markets',
#     'acronym': '',
#     'mic': 'OTCM',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.otcmarkets.com'}},
#   {'name': 'Roche Holding AG',
#    'symbol': 'RHHVF',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'OTC Markets',
#     'acronym': '',
#     'mic': 'OTCM',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.otcmarkets.com'}},
#   {'name': 'AT&T Inc',
#    'symbol': 'T',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Unitedhealth Group Inc',
#    'symbol': 'UNH',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Bank Of America Corp',
#    'symbol': 'BAC',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Home Depot Inc',
#    'symbol': 'HD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Intel Corp',
#    'symbol': 'INTC',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Coca-Cola Company',
#    'symbol': 'KO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Verizon Communications Inc',
#    'symbol': 'VZ',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Roche Holding AG',
#    'symbol': 'RHHBY',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'OTC Markets',
#     'acronym': '',
#     'mic': 'OTCM',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.otcmarkets.com'}},
#   {'name': 'Exxon Mobil Corp',
#    'symbol': 'XOM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Walt Disney Co (The)',
#    'symbol': 'DIS',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Merck & Co Inc',
#    'symbol': 'MRK',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Novartis AG',
#    'symbol': 'NVS',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Comcast Corp - Class A',
#    'symbol': 'CMCSA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Pfizer Inc',
#    'symbol': 'PFE',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'PepsiCo Inc',
#    'symbol': 'PEP',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Toyota Motor Corporation',
#    'symbol': 'TM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Chevron Corp',
#    'symbol': 'CVX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Adobe Inc',
#    'symbol': 'ADBE',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Cisco Systems Inc',
#    'symbol': 'CSCO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Wells Fargo & Company',
#    'symbol': 'WFC',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'NVIDIA Corp',
#    'symbol': 'NVDA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Netflix Inc',
#    'symbol': 'NFLX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Oracle Corp',
#    'symbol': 'ORCL',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Boeing Company',
#    'symbol': 'BA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'China Mobile Ltd ADR',
#    'symbol': 'CHL',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Salesforce Inc',
#    'symbol': 'CRM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Sap SE',
#    'symbol': 'SAP',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'McDonald`s Corp',
#    'symbol': 'MCD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Nike Inc - Class B',
#    'symbol': 'NKE',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Abbott Laboratories',
#    'symbol': 'ABT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Citigroup Inc',
#    'symbol': 'C',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Medtronic Plc',
#    'symbol': 'MDT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'HSBC Holdings plc',
#    'symbol': 'HSBC',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Tesla Inc',
#    'symbol': 'TSLA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Costco Wholesale Corp',
#    'symbol': 'COST',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Bristol-Myers Squibb Company',
#    'symbol': 'BMY',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': "HSBC HOLDINGS PLC ADR EACH REPR 1/40 PREF SERIES '",
#    'symbol': 'HSBC/PA',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'PayPal Holdings Inc',
#    'symbol': 'PYPL',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Philip Morris International Inc',
#    'symbol': 'PM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'NextEra Energy Inc',
#    'symbol': 'NEE',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Abbvie Inc',
#    'symbol': 'ABBV',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Lilly(Eli) & Company',
#    'symbol': 'LLY',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'AMGEN Inc',
#    'symbol': 'AMGN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Sanofi',
#    'symbol': 'SNY',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Thermo Fisher Scientific Inc',
#    'symbol': 'TMO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'ASML Holding NV',
#    'symbol': 'ASML',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Astrazeneca plc',
#    'symbol': 'AZN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Accenture plc - Class A',
#    'symbol': 'ACN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'International Business Machines Corp',
#    'symbol': 'IBM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Honeywell International Inc',
#    'symbol': 'HON',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'UNITED TECHNOLOGIES CORP',
#    'symbol': 'UTX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'TotalEnergies SE',
#    'symbol': 'TOT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Broadcom Inc',
#    'symbol': 'AVGO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Texas Instruments Inc',
#    'symbol': 'TXN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Novo Nordisk',
#    'symbol': 'NVO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Union Pacific Corp',
#    'symbol': 'UNP',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Royal Bank Of Canada',
#    'symbol': 'RY',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'BP plc',
#    'symbol': 'BP',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Lockheed Martin Corp',
#    'symbol': 'LMT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'American Tower Corp',
#    'symbol': 'AMT',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Linde Plc.',
#    'symbol': 'LIN',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'GSK Plc',
#    'symbol': 'GSK',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Danaher Corp',
#    'symbol': 'DHR',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Charter Communications Inc - Class A',
#    'symbol': 'CHTR',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'HDFC Bank Ltd',
#    'symbol': 'HDB',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'General Electric Company',
#    'symbol': 'GE',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Starbucks Corp',
#    'symbol': 'SBUX',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Anheuser-Busch InBev SA/NV',
#    'symbol': 'BUD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Gilead Sciences Inc',
#    'symbol': 'GILD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'Toronto Dominion Bank',
#    'symbol': 'TD',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Sinopec Shanghai Petrochemical Co. Ltd',
#    'symbol': 'SHI',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Qualcomm Inc',
#    'symbol': 'QCOM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'NASDAQ Stock Exchange',
#     'acronym': 'NASDAQ',
#     'mic': 'XNAS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nasdaq.com'}},
#   {'name': 'American Express Company',
#    'symbol': 'AXP',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': "ROYAL DUTCH SHELL ADR EA REP 2 CL'A' EUR0.07",
#    'symbol': 'RDS.A',
#    'has_intraday': False,
#    'has_eod': False,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Fidelity National Information Services Inc',
#    'symbol': 'FIS',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'British American Tobacco Plc',
#    'symbol': 'BTI',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': '3M Company',
#    'symbol': 'MMM',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Lowe`s Cos. Inc',
#    'symbol': 'LOW',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': 'Diageo plc',
#    'symbol': 'DEO',
#    'has_intraday': False,
#    'has_eod': True,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}},
#   {'name': "ROYAL DUTCH SHELL ADR EA REP 2 CL'B' EUR0.07",
#    'symbol': 'RDS.B',
#    'has_intraday': False,
#    'has_eod': False,
#    'country': None,
#    'stock_exchange': {'name': 'New York Stock Exchange',
#     'acronym': 'NYSE',
#     'mic': 'XNYS',
#     'country': 'USA',
#     'country_code': 'US',
#     'city': 'New York',
#     'website': 'www.nyse.com'}}]}

# %%
companies = response_json['data']

# %%
df = pd.json_normalize(companies, meta=['name'])
print(df)
# Out:
#                                             name symbol  has_intraday  \
# 0                          Microsoft Corporation   MSFT         False
# 1                                      Apple Inc   AAPL         False
# 2                                 Amazon.com Inc   AMZN         False
# 3                         Alphabet Inc - Class C   GOOG         False
# 4                         Alphabet Inc - Class A  GOOGL         False
# ..                                           ...    ...           ...
# 95                  British American Tobacco Plc    BTI         False
# 96                                    3M Company    MMM         False
# 97                               Lowe`s Cos. Inc    LOW         False
# 98                                    Diageo plc    DEO         False
# 99  ROYAL DUTCH SHELL ADR EA REP 2 CL'B' EUR0.07  RDS.B         False
#
#     has_eod country      stock_exchange.name stock_exchange.acronym  \
# 0      True    None    NASDAQ Stock Exchange                 NASDAQ
# 1      True    None    NASDAQ Stock Exchange                 NASDAQ
# 2      True    None    NASDAQ Stock Exchange                 NASDAQ
# 3      True    None    NASDAQ Stock Exchange                 NASDAQ
# 4      True    None    NASDAQ Stock Exchange                 NASDAQ
# ..      ...     ...                      ...                    ...
# 95     True    None  New York Stock Exchange                   NYSE
# 96     True    None  New York Stock Exchange                   NYSE
# 97     True    None  New York Stock Exchange                   NYSE
# 98     True    None  New York Stock Exchange                   NYSE
# 99    False    None  New York Stock Exchange                   NYSE
#
#    stock_exchange.mic stock_exchange.country stock_exchange.country_code  \
# 0                XNAS                    USA                          US
# 1                XNAS                    USA                          US
# 2                XNAS                    USA                          US
# 3                XNAS                    USA                          US
# 4                XNAS                    USA                          US
# ..                ...                    ...                         ...
# 95               XNYS                    USA                          US
# 96               XNYS                    USA                          US
# 97               XNYS                    USA                          US
# 98               XNYS                    USA                          US
# 99               XNYS                    USA                          US
#
#    stock_exchange.city stock_exchange.website
# 0             New York         www.nasdaq.com
# 1             New York         www.nasdaq.com
# 2             New York         www.nasdaq.com
# 3             New York         www.nasdaq.com
# 4             New York         www.nasdaq.com
# ..                 ...                    ...
# 95            New York           www.nyse.com
# 96            New York           www.nyse.com
# 97            New York           www.nyse.com
# 98            New York           www.nyse.com
# 99            New York           www.nyse.com
#
# [100 rows x 12 columns]

# %%
url = "https://api.marketstack.com/v1/splits?access_key=" + api_key
querystring = {"symbols":"MSFT"}
response = requests.get(url, params=querystring)
print(response.json())
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 9, 'total': 9}, 'data': [{'date': '2003-02-18', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1999-03-29', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1998-02-23', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1996-12-09', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1994-05-23', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1992-06-15', 'split_factor': 1.5, 'symbol': 'MSFT'}, {'date': '1991-06-27', 'split_factor': 1.5, 'symbol': 'MSFT'}, {'date': '1990-04-16', 'split_factor': 2.0, 'symbol': 'MSFT'}, {'date': '1987-09-21', 'split_factor': 2.0, 'symbol': 'MSFT'}]}

# %%
url = "https://api.marketstack.com/v1/eod?access_key=" + api_key
querystring = {"symbols":"MSFT","date_from":"2023-12-01", "date_to":"2024-12-01"}
response = requests.get(url, params=querystring)
print(response.json())
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 241}, 'data': [{'open': 420.09, 'high': 424.88, 'low': 417.8, 'close': 423.46, 'volume': 16271900.0, 'adj_high': 424.88, 'adj_low': 417.8, 'adj_close': 423.46, 'adj_open': 420.09, 'adj_volume': 16271921.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-29T00:00:00+0000'}, {'open': 425.105, 'high': 427.2299, 'low': 422.02, 'close': 422.99, 'volume': 18332444.0, 'adj_high': 427.2299, 'adj_low': 422.02, 'adj_close': 422.99, 'adj_open': 425.105, 'adj_volume': 18332444.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-27T00:00:00+0000'}, {'open': 419.59, 'high': 429.04, 'low': 418.85, 'close': 427.99, 'volume': 23439600.0, 'adj_high': 429.0414, 'adj_low': 418.85, 'adj_close': 427.99, 'adj_open': 419.585, 'adj_volume': 23458889.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-26T00:00:00+0000'}, {'open': 418.38, 'high': 421.08, 'low': 414.85, 'close': 418.79, 'volume': 27651300.0, 'adj_high': 421.08, 'adj_low': 414.85, 'adj_close': 418.79, 'adj_open': 418.38, 'adj_volume': 27691090.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-25T00:00:00+0000'}, {'open': 411.37, 'high': 417.4, 'low': 411.06, 'close': 417.0, 'volume': 24802100.0, 'adj_high': 417.4, 'adj_low': 411.06, 'adj_close': 417.0, 'adj_open': 411.365, 'adj_volume': 24814626.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-22T00:00:00+0000'}, {'open': 419.5, 'high': 419.78, 'low': 410.29, 'close': 412.87, 'volume': 20745300.0, 'adj_high': 419.78, 'adj_low': 410.2887, 'adj_close': 412.87, 'adj_open': 419.5, 'adj_volume': 20780162.0, 'split_factor': 1.0, 'dividend': 0.83, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-21T00:00:00+0000'}, {'open': 416.87, 'high': 417.29, 'low': 410.58, 'close': 415.49, 'volume': 19166200.0, 'adj_high': 417.29, 'adj_low': 410.58, 'adj_close': 414.66, 'adj_open': 416.87, 'adj_volume': 19191655.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-20T00:00:00+0000'}, {'open': 413.11, 'high': 417.94, 'low': 411.55, 'close': 417.79, 'volume': 18111900.0, 'adj_high': 417.94, 'adj_low': 411.55, 'adj_close': 417.79, 'adj_open': 413.11, 'adj_volume': 18133529.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-19T00:00:00+0000'}, {'open': 414.87, 'high': 418.4037, 'low': 412.1, 'close': 415.76, 'volume': 23983845.0, 'adj_high': 418.4037, 'adj_low': 412.1, 'adj_close': 415.76, 'adj_open': 414.87, 'adj_volume': 24742013.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-18T00:00:00+0000'}, {'open': 419.82, 'high': 422.8, 'low': 413.64, 'close': 415.0, 'volume': 28196600.0, 'adj_high': 422.8, 'adj_low': 413.64, 'adj_close': 415.0, 'adj_open': 419.82, 'adj_volume': 28247644.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-15T00:00:00+0000'}, {'open': 425.0, 'high': 428.17, 'low': 420.0, 'close': 426.89, 'volume': 30213400.0, 'adj_high': 428.17, 'adj_low': 420.0, 'adj_close': 426.89, 'adj_open': 425.0, 'adj_volume': 30246881.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-14T00:00:00+0000'}, {'open': 421.64, 'high': 429.33, 'low': 418.21, 'close': 425.2, 'volume': 21477900.0, 'adj_high': 429.325, 'adj_low': 418.21, 'adj_close': 425.2, 'adj_open': 421.64, 'adj_volume': 21502185.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'exchange': 'XNAS', 'date': '2024-11-13T00:00:00+0000'}, {'open': 418.25, 'high': 424.44, 'low': 417.2, 'close': 423.03, 'volume': 19382500.0, 'adj_high': 424.44, 'adj_low': 417.2, 'adj_close': 423.03, 'adj_open': 418.25, 'adj_volume': 19401204.0, 'split_factor': 1.0, 'dividend': 0.0, 'symbol': 'MSFT', 'e ...

# %%
historical_data = response.json()['data']
historical_data
# Out:
# [{'open': 420.09,
#   'high': 424.88,
#   'low': 417.8,
#   'close': 423.46,
#   'volume': 16271900.0,
#   'adj_high': 424.88,
#   'adj_low': 417.8,
#   'adj_close': 423.46,
#   'adj_open': 420.09,
#   'adj_volume': 16271921.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-29T00:00:00+0000'},
#  {'open': 425.105,
#   'high': 427.2299,
#   'low': 422.02,
#   'close': 422.99,
#   'volume': 18332444.0,
#   'adj_high': 427.2299,
#   'adj_low': 422.02,
#   'adj_close': 422.99,
#   'adj_open': 425.105,
#   'adj_volume': 18332444.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-27T00:00:00+0000'},
#  {'open': 419.59,
#   'high': 429.04,
#   'low': 418.85,
#   'close': 427.99,
#   'volume': 23439600.0,
#   'adj_high': 429.0414,
#   'adj_low': 418.85,
#   'adj_close': 427.99,
#   'adj_open': 419.585,
#   'adj_volume': 23458889.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-26T00:00:00+0000'},
#  {'open': 418.38,
#   'high': 421.08,
#   'low': 414.85,
#   'close': 418.79,
#   'volume': 27651300.0,
#   'adj_high': 421.08,
#   'adj_low': 414.85,
#   'adj_close': 418.79,
#   'adj_open': 418.38,
#   'adj_volume': 27691090.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-25T00:00:00+0000'},
#  {'open': 411.37,
#   'high': 417.4,
#   'low': 411.06,
#   'close': 417.0,
#   'volume': 24802100.0,
#   'adj_high': 417.4,
#   'adj_low': 411.06,
#   'adj_close': 417.0,
#   'adj_open': 411.365,
#   'adj_volume': 24814626.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-22T00:00:00+0000'},
#  {'open': 419.5,
#   'high': 419.78,
#   'low': 410.29,
#   'close': 412.87,
#   'volume': 20745300.0,
#   'adj_high': 419.78,
#   'adj_low': 410.2887,
#   'adj_close': 412.87,
#   'adj_open': 419.5,
#   'adj_volume': 20780162.0,
#   'split_factor': 1.0,
#   'dividend': 0.83,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-21T00:00:00+0000'},
#  {'open': 416.87,
#   'high': 417.29,
#   'low': 410.58,
#   'close': 415.49,
#   'volume': 19166200.0,
#   'adj_high': 417.29,
#   'adj_low': 410.58,
#   'adj_close': 414.66,
#   'adj_open': 416.87,
#   'adj_volume': 19191655.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-20T00:00:00+0000'},
#  {'open': 413.11,
#   'high': 417.94,
#   'low': 411.55,
#   'close': 417.79,
#   'volume': 18111900.0,
#   'adj_high': 417.94,
#   'adj_low': 411.55,
#   'adj_close': 417.79,
#   'adj_open': 413.11,
#   'adj_volume': 18133529.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-19T00:00:00+0000'},
#  {'open': 414.87,
#   'high': 418.4037,
#   'low': 412.1,
#   'close': 415.76,
#   'volume': 23983845.0,
#   'adj_high': 418.4037,
#   'adj_low': 412.1,
#   'adj_close': 415.76,
#   'adj_open': 414.87,
#   'adj_volume': 24742013.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-18T00:00:00+0000'},
#  {'open': 419.82,
#   'high': 422.8,
#   'low': 413.64,
#   'close': 415.0,
#   'volume': 28196600.0,
#   'adj_high': 422.8,
#   'adj_low': 413.64,
#   'adj_close': 415.0,
#   'adj_open': 419.82,
#   'adj_volume': 28247644.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-15T00:00:00+0000'},
#  {'open': 425.0,
#   'high': 428.17,
#   'low': 420.0,
#   'close': 426.89,
#   'volume': 30213400.0,
#   'adj_high': 428.17,
#   'adj_low': 420.0,
#   'adj_close': 426.89,
#   'adj_open': 425.0,
#   'adj_volume': 30246881.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-14T00:00:00+0000'},
#  {'open': 421.64,
#   'high': 429.33,
#   'low': 418.21,
#   'close': 425.2,
#   'volume': 21477900.0,
#   'adj_high': 429.325,
#   'adj_low': 418.21,
#   'adj_close': 425.2,
#   'adj_open': 421.64,
#   'adj_volume': 21502185.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-13T00:00:00+0000'},
#  {'open': 418.25,
#   'high': 424.44,
#   'low': 417.2,
#   'close': 423.03,
#   'volume': 19382500.0,
#   'adj_high': 424.44,
#   'adj_low': 417.2,
#   'adj_close': 423.03,
#   'adj_open': 418.25,
#   'adj_volume': 19401204.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-12T00:00:00+0000'},
#  {'open': 422.52,
#   'high': 424.81,
#   'low': 416.0,
#   'close': 418.01,
#   'volume': 24473800.0,
#   'adj_high': 424.81,
#   'adj_low': 416.0,
#   'adj_close': 418.01,
#   'adj_open': 422.515,
#   'adj_volume': 24503321.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-11T00:00:00+0000'},
#  {'open': 425.32,
#   'high': 426.5,
#   'low': 421.78,
#   'close': 422.54,
#   'volume': 16875500.0,
#   'adj_high': 426.5,
#   'adj_low': 421.78,
#   'adj_close': 422.54,
#   'adj_open': 425.32,
#   'adj_volume': 16891414.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-08T00:00:00+0000'},
#  {'open': 421.12,
#   'high': 426.85,
#   'low': 419.88,
#   'close': 425.43,
#   'volume': 19615445.0,
#   'adj_high': 426.85,
#   'adj_low': 419.88,
#   'adj_close': 425.43,
#   'adj_open': 421.28,
#   'adj_volume': 19901782.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-07T00:00:00+0000'},
#  {'open': 412.43,
#   'high': 420.43,
#   'low': 410.52,
#   'close': 420.18,
#   'volume': 26429288.0,
#   'adj_high': 420.45,
#   'adj_low': 410.52,
#   'adj_close': 420.18,
#   'adj_open': 412.42,
#   'adj_volume': 26681842.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-06T00:00:00+0000'},
#  {'open': 408.33,
#   'high': 414.9,
#   'low': 408.08,
#   'close': 411.46,
#   'volume': 17429735.0,
#   'adj_high': 414.9,
#   'adj_low': 408.08,
#   'adj_close': 411.46,
#   'adj_open': 408.37,
#   'adj_volume': 17626011.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-05T00:00:00+0000'},
#  {'open': 409.855,
#   'high': 410.41,
#   'low': 405.575,
#   'close': 408.46,
#   'volume': 19284886.0,
#   'adj_high': 410.415,
#   'adj_low': 405.5713,
#   'adj_close': 408.46,
#   'adj_open': 409.8,
#   'adj_volume': 19672286.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-04T00:00:00+0000'},
#  {'open': 409.01,
#   'high': 415.5,
#   'low': 407.5,
#   'close': 410.37,
#   'volume': 24209400.0,
#   'adj_high': 415.5,
#   'adj_low': 407.5,
#   'adj_close': 410.37,
#   'adj_open': 409.01,
#   'adj_volume': 24230442.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-11-01T00:00:00+0000'},
#  {'open': 415.96,
#   'high': 416.065,
#   'low': 406.3,
#   'close': 406.35,
#   'volume': 53473867.0,
#   'adj_high': 416.16,
#   'adj_low': 406.3,
#   'adj_close': 406.35,
#   'adj_open': 415.36,
#   'adj_volume': 53970981.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-31T00:00:00+0000'},
#  {'open': 437.435,
#   'high': 438.5,
#   'low': 432.1,
#   'close': 432.53,
#   'volume': 29749149.0,
#   'adj_high': 438.5,
#   'adj_low': 432.1,
#   'adj_close': 432.53,
#   'adj_open': 437.435,
#   'adj_volume': 29749149.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-30T00:00:00+0000'},
#  {'open': 428.0,
#   'high': 433.17,
#   'low': 425.8,
#   'close': 431.95,
#   'volume': 17581800.0,
#   'adj_high': 433.17,
#   'adj_low': 425.8001,
#   'adj_close': 431.95,
#   'adj_open': 428.0,
#   'adj_volume': 17644080.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-29T00:00:00+0000'},
#  {'open': 431.655,
#   'high': 431.94,
#   'low': 426.34,
#   'close': 426.59,
#   'volume': 14003953.0,
#   'adj_high': 431.94,
#   'adj_low': 426.3,
#   'adj_close': 426.59,
#   'adj_open': 431.655,
#   'adj_volume': 14882444.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-28T00:00:00+0000'},
#  {'open': 426.76,
#   'high': 432.52,
#   'low': 426.57,
#   'close': 428.15,
#   'volume': 16888400.0,
#   'adj_high': 432.52,
#   'adj_low': 426.565,
#   'adj_close': 428.15,
#   'adj_open': 426.76,
#   'adj_volume': 16899064.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-25T00:00:00+0000'},
#  {'open': 425.33,
#   'high': 425.98,
#   'low': 422.4,
#   'close': 424.73,
#   'volume': 13562400.0,
#   'adj_high': 425.9782,
#   'adj_low': 422.4,
#   'adj_close': 424.73,
#   'adj_open': 425.325,
#   'adj_volume': 13581631.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-24T00:00:00+0000'},
#  {'open': 430.855,
#   'high': 431.08,
#   'low': 422.53,
#   'close': 424.6,
#   'volume': 19654379.0,
#   'adj_high': 431.08,
#   'adj_low': 422.53,
#   'adj_close': 424.6,
#   'adj_open': 430.855,
#   'adj_volume': 19654379.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-23T00:00:00+0000'},
#  {'open': 419.0,
#   'high': 430.57,
#   'low': 418.0479,
#   'close': 427.51,
#   'volume': 23863170.0,
#   'adj_high': 430.5793,
#   'adj_low': 418.04,
#   'adj_close': 427.51,
#   'adj_open': 418.49,
#   'adj_volume': 25482197.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-22T00:00:00+0000'},
#  {'open': 416.12,
#   'high': 418.96,
#   'low': 413.8,
#   'close': 418.78,
#   'volume': 13284766.0,
#   'adj_high': 418.96,
#   'adj_low': 413.7501,
#   'adj_close': 418.78,
#   'adj_open': 416.12,
#   'adj_volume': 14206115.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-21T00:00:00+0000'},
#  {'open': 417.14,
#   'high': 419.65,
#   'low': 416.26,
#   'close': 418.16,
#   'volume': 17138600.0,
#   'adj_high': 419.65,
#   'adj_low': 416.2601,
#   'adj_close': 418.16,
#   'adj_open': 417.14,
#   'adj_volume': 17145317.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-18T00:00:00+0000'},
#  {'open': 422.36,
#   'high': 422.5,
#   'low': 415.59,
#   'close': 416.72,
#   'volume': 14803400.0,
#   'adj_high': 422.5,
#   'adj_low': 415.59,
#   'adj_close': 416.72,
#   'adj_open': 422.36,
#   'adj_volume': 14820004.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-17T00:00:00+0000'},
#  {'open': 415.02,
#   'high': 416.36,
#   'low': 410.48,
#   'close': 416.12,
#   'volume': 15062246.0,
#   'adj_high': 416.36,
#   'adj_low': 410.48,
#   'adj_close': 416.12,
#   'adj_open': 415.17,
#   'adj_volume': 15508932.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-16T00:00:00+0000'},
#  {'open': 422.18,
#   'high': 422.48,
#   'low': 415.26,
#   'close': 418.74,
#   'volume': 18885000.0,
#   'adj_high': 422.48,
#   'adj_low': 415.26,
#   'adj_close': 418.74,
#   'adj_open': 422.18,
#   'adj_volume': 18900201.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-15T00:00:00+0000'},
#  {'open': 417.85,
#   'high': 424.04,
#   'low': 417.52,
#   'close': 419.14,
#   'volume': 16417434.0,
#   'adj_high': 424.04,
#   'adj_low': 417.52,
#   'adj_close': 419.14,
#   'adj_open': 417.77,
#   'adj_volume': 16653086.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-14T00:00:00+0000'},
#  {'open': 416.135,
#   'high': 417.13,
#   'low': 413.25,
#   'close': 416.32,
#   'volume': 14144944.0,
#   'adj_high': 417.13,
#   'adj_low': 413.25,
#   'adj_close': 416.32,
#   'adj_open': 416.135,
#   'adj_volume': 14144944.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-11T00:00:00+0000'},
#  {'open': 415.23,
#   'high': 417.35,
#   'low': 413.15,
#   'close': 415.84,
#   'volume': 13807800.0,
#   'adj_high': 417.35,
#   'adj_low': 413.15,
#   'adj_close': 415.84,
#   'adj_open': 415.225,
#   'adj_volume': 13848376.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-10T00:00:00+0000'},
#  {'open': 415.86,
#   'high': 420.38,
#   'low': 414.3,
#   'close': 417.46,
#   'volume': 14974257.0,
#   'adj_high': 420.38,
#   'adj_low': 414.3,
#   'adj_close': 417.46,
#   'adj_open': 415.86,
#   'adj_volume': 14974257.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-09T00:00:00+0000'},
#  {'open': 410.9,
#   'high': 415.66,
#   'low': 408.17,
#   'close': 414.71,
#   'volume': 19115000.0,
#   'adj_high': 415.66,
#   'adj_low': 408.17,
#   'adj_close': 414.71,
#   'adj_open': 410.9,
#   'adj_volume': 19229261.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-08T00:00:00+0000'},
#  {'open': 416.0,
#   'high': 417.11,
#   'low': 409.0,
#   'close': 409.54,
#   'volume': 19536309.0,
#   'adj_high': 417.11,
#   'adj_low': 409.0,
#   'adj_close': 409.54,
#   'adj_open': 416.0,
#   'adj_volume': 20919761.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-07T00:00:00+0000'},
#  {'open': 418.24,
#   'high': 419.75,
#   'low': 414.97,
#   'close': 416.06,
#   'volume': 19169700.0,
#   'adj_high': 419.75,
#   'adj_low': 414.97,
#   'adj_close': 416.06,
#   'adj_open': 418.24,
#   'adj_volume': 19190913.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-04T00:00:00+0000'},
#  {'open': 417.86,
#   'high': 419.5499,
#   'low': 414.3,
#   'close': 416.54,
#   'volume': 13460138.0,
#   'adj_high': 419.55,
#   'adj_low': 414.29,
#   'adj_close': 416.54,
#   'adj_open': 417.63,
#   'adj_volume': 13686421.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-03T00:00:00+0000'},
#  {'open': 422.59,
#   'high': 422.77,
#   'low': 416.71,
#   'close': 417.13,
#   'volume': 16008500.0,
#   'adj_high': 422.82,
#   'adj_low': 416.71,
#   'adj_close': 417.13,
#   'adj_open': 422.58,
#   'adj_volume': 16582257.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-02T00:00:00+0000'},
#  {'open': 428.38,
#   'high': 428.47,
#   'low': 418.825,
#   'close': 420.69,
#   'volume': 18823041.0,
#   'adj_high': 428.48,
#   'adj_low': 418.81,
#   'adj_close': 420.69,
#   'adj_open': 428.45,
#   'adj_volume': 19092945.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-10-01T00:00:00+0000'},
#  {'open': 428.21,
#   'high': 430.42,
#   'low': 425.37,
#   'close': 430.3,
#   'volume': 16807300.0,
#   'adj_high': 430.42,
#   'adj_low': 425.37,
#   'adj_close': 430.3,
#   'adj_open': 428.21,
#   'adj_volume': 16854606.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-30T00:00:00+0000'},
#  {'open': 431.52,
#   'high': 431.85,
#   'low': 427.47,
#   'close': 428.02,
#   'volume': 14888600.0,
#   'adj_high': 431.85,
#   'adj_low': 427.47,
#   'adj_close': 428.02,
#   'adj_open': 431.52,
#   'adj_volume': 14896131.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-27T00:00:00+0000'},
#  {'open': 435.09,
#   'high': 435.3,
#   'low': 429.13,
#   'close': 431.31,
#   'volume': 14454500.0,
#   'adj_high': 435.3,
#   'adj_low': 429.13,
#   'adj_close': 431.31,
#   'adj_open': 435.085,
#   'adj_volume': 14492044.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-26T00:00:00+0000'},
#  {'open': 429.83,
#   'high': 433.12,
#   'low': 428.57,
#   'close': 432.11,
#   'volume': 13335000.0,
#   'adj_high': 433.119,
#   'adj_low': 428.57,
#   'adj_close': 432.11,
#   'adj_open': 429.83,
#   'adj_volume': 13396364.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-25T00:00:00+0000'},
#  {'open': 433.0,
#   'high': 433.35,
#   'low': 426.1,
#   'close': 429.17,
#   'volume': 16919500.0,
#   'adj_high': 433.35,
#   'adj_low': 426.1,
#   'adj_close': 429.17,
#   'adj_open': 433.0,
#   'adj_volume': 17015754.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-24T00:00:00+0000'},
#  {'open': 434.28,
#   'high': 436.46,
#   'low': 430.39,
#   'close': 433.51,
#   'volume': 15115900.0,
#   'adj_high': 436.46,
#   'adj_low': 430.3889,
#   'adj_close': 433.51,
#   'adj_open': 434.28,
#   'adj_volume': 15128891.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-23T00:00:00+0000'},
#  {'open': 437.22,
#   'high': 439.24,
#   'low': 434.22,
#   'close': 435.27,
#   'volume': 55155300.0,
#   'adj_high': 439.24,
#   'adj_low': 434.22,
#   'adj_close': 435.27,
#   'adj_open': 437.22,
#   'adj_volume': 55167106.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-20T00:00:00+0000'},
#  {'open': 441.23,
#   'high': 441.5,
#   'low': 436.9,
#   'close': 438.69,
#   'volume': 21674300.0,
#   'adj_high': 441.5,
#   'adj_low': 436.9,
#   'adj_close': 438.69,
#   'adj_open': 441.225,
#   'adj_volume': 21706559.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-19T00:00:00+0000'},
#  {'open': 435.0,
#   'high': 436.03,
#   'low': 430.41,
#   'close': 430.81,
#   'volume': 18856600.0,
#   'adj_high': 436.03,
#   'adj_low': 430.41,
#   'adj_close': 430.81,
#   'adj_open': 435.0,
#   'adj_volume': 18898042.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-18T00:00:00+0000'},
#  {'open': 440.23,
#   'high': 441.85,
#   'low': 432.27,
#   'close': 435.15,
#   'volume': 18858500.0,
#   'adj_high': 441.85,
#   'adj_low': 432.27,
#   'adj_close': 435.15,
#   'adj_open': 440.23,
#   'adj_volume': 18874231.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-17T00:00:00+0000'},
#  {'open': 430.6,
#   'high': 433.53,
#   'low': 428.22,
#   'close': 431.34,
#   'volume': 13768200.0,
#   'adj_high': 433.53,
#   'adj_low': 428.22,
#   'adj_close': 431.34,
#   'adj_open': 430.6,
#   'adj_volume': 13834697.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-16T00:00:00+0000'},
#  {'open': 425.83,
#   'high': 431.83,
#   'low': 425.46,
#   'close': 430.59,
#   'volume': 15861900.0,
#   'adj_high': 431.83,
#   'adj_low': 425.46,
#   'adj_close': 430.59,
#   'adj_open': 425.825,
#   'adj_volume': 15874555.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-13T00:00:00+0000'},
#  {'open': 423.31,
#   'high': 427.37,
#   'low': 419.75,
#   'close': 427.0,
#   'volume': 17395700.0,
#   'adj_high': 427.3692,
#   'adj_low': 419.75,
#   'adj_close': 427.0,
#   'adj_open': 423.31,
#   'adj_volume': 17418759.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-12T00:00:00+0000'},
#  {'open': 415.5,
#   'high': 423.99,
#   'low': 409.58,
#   'close': 423.04,
#   'volume': 19233600.0,
#   'adj_high': 423.99,
#   'adj_low': 409.58,
#   'adj_close': 423.04,
#   'adj_open': 415.5,
#   'adj_volume': 19266923.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-11T00:00:00+0000'},
#  {'open': 408.2,
#   'high': 416.33,
#   'low': 407.7,
#   'close': 414.2,
#   'volume': 19573000.0,
#   'adj_high': 416.33,
#   'adj_low': 407.7,
#   'adj_close': 414.2,
#   'adj_open': 408.2,
#   'adj_volume': 19594287.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-10T00:00:00+0000'},
#  {'open': 407.24,
#   'high': 408.65,
#   'low': 402.15,
#   'close': 405.72,
#   'volume': 15275400.0,
#   'adj_high': 408.65,
#   'adj_low': 402.15,
#   'adj_close': 405.72,
#   'adj_open': 407.24,
#   'adj_volume': 15295134.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-09T00:00:00+0000'},
#  {'open': 409.06,
#   'high': 410.65,
#   'low': 400.8,
#   'close': 401.7,
#   'volume': 19382200.0,
#   'adj_high': 410.65,
#   'adj_low': 400.8,
#   'adj_close': 401.7,
#   'adj_open': 409.06,
#   'adj_volume': 19609526.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-06T00:00:00+0000'},
#  {'open': 408.205,
#   'high': 413.1,
#   'low': 406.13,
#   'close': 408.39,
#   'volume': 14089837.0,
#   'adj_high': 413.1,
#   'adj_low': 406.13,
#   'adj_close': 408.39,
#   'adj_open': 407.62,
#   'adj_volume': 14195516.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-05T00:00:00+0000'},
#  {'open': 405.63,
#   'high': 411.24,
#   'low': 404.37,
#   'close': 408.9,
#   'volume': 14860891.0,
#   'adj_high': 411.24,
#   'adj_low': 404.37,
#   'adj_close': 408.9,
#   'adj_open': 405.91,
#   'adj_volume': 14886710.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-04T00:00:00+0000'},
#  {'open': 417.99,
#   'high': 419.88,
#   'low': 407.03,
#   'close': 409.44,
#   'volume': 19788534.0,
#   'adj_high': 419.88,
#   'adj_low': 407.03,
#   'adj_close': 409.44,
#   'adj_open': 417.91,
#   'adj_volume': 20313603.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-09-03T00:00:00+0000'},
#  {'open': 415.6,
#   'high': 417.49,
#   'low': 412.13,
#   'close': 417.14,
#   'volume': 24308324.0,
#   'adj_high': 417.49,
#   'adj_low': 412.13,
#   'adj_close': 417.14,
#   'adj_open': 415.6,
#   'adj_volume': 24308324.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-30T00:00:00+0000'},
#  {'open': 414.94,
#   'high': 422.05,
#   'low': 410.6,
#   'close': 413.12,
#   'volume': 17030800.0,
#   'adj_high': 422.05,
#   'adj_low': 410.6,
#   'adj_close': 413.12,
#   'adj_open': 414.94,
#   'adj_volume': 17045241.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-29T00:00:00+0000'},
#  {'open': 414.88,
#   'high': 415.0,
#   'low': 407.31,
#   'close': 410.6,
#   'volume': 14846300.0,
#   'adj_high': 415.0,
#   'adj_low': 407.31,
#   'adj_close': 410.6,
#   'adj_open': 414.88,
#   'adj_volume': 14882660.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-28T00:00:00+0000'},
#  {'open': 412.86,
#   'high': 414.36,
#   'low': 410.25,
#   'close': 413.84,
#   'volume': 13473900.0,
#   'adj_high': 414.36,
#   'adj_low': 410.25,
#   'adj_close': 413.84,
#   'adj_open': 412.86,
#   'adj_volume': 13492911.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-27T00:00:00+0000'},
#  {'open': 416.37,
#   'high': 417.28,
#   'low': 411.34,
#   'close': 413.49,
#   'volume': 13134700.0,
#   'adj_high': 417.2799,
#   'adj_low': 411.34,
#   'adj_close': 413.49,
#   'adj_open': 416.365,
#   'adj_volume': 13152830.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-26T00:00:00+0000'},
#  {'open': 416.98,
#   'high': 419.26,
#   'low': 412.09,
#   'close': 416.79,
#   'volume': 18473000.0,
#   'adj_high': 419.26,
#   'adj_low': 412.09,
#   'adj_close': 416.79,
#   'adj_open': 416.98,
#   'adj_volume': 18493784.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-23T00:00:00+0000'},
#  {'open': 424.36,
#   'high': 426.79,
#   'low': 414.61,
#   'close': 415.55,
#   'volume': 19348500.0,
#   'adj_high': 426.7899,
#   'adj_low': 414.61,
#   'adj_close': 415.55,
#   'adj_open': 424.36,
#   'adj_volume': 19361901.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-22T00:00:00+0000'},
#  {'open': 424.08,
#   'high': 426.4,
#   'low': 421.72,
#   'close': 424.14,
#   'volume': 15744000.0,
#   'adj_high': 426.4,
#   'adj_low': 421.72,
#   'adj_close': 424.14,
#   'adj_open': 424.075,
#   'adj_volume': 16067298.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-21T00:00:00+0000'},
#  {'open': 421.7,
#   'high': 425.86,
#   'low': 421.64,
#   'close': 424.8,
#   'volume': 16352000.0,
#   'adj_high': 425.86,
#   'adj_low': 421.64,
#   'adj_close': 424.8,
#   'adj_open': 421.7,
#   'adj_volume': 16387581.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-20T00:00:00+0000'},
#  {'open': 418.96,
#   'high': 421.75,
#   'low': 416.46,
#   'close': 421.53,
#   'volume': 15210800.0,
#   'adj_high': 421.75,
#   'adj_low': 416.46,
#   'adj_close': 421.53,
#   'adj_open': 418.96,
#   'adj_volume': 15233957.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-19T00:00:00+0000'},
#  {'open': 420.6,
#   'high': 421.34,
#   'low': 417.3,
#   'close': 418.47,
#   'volume': 22757000.0,
#   'adj_high': 421.34,
#   'adj_low': 417.3,
#   'adj_close': 418.47,
#   'adj_open': 420.6,
#   'adj_volume': 22775593.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-16T00:00:00+0000'},
#  {'open': 419.8,
#   'high': 421.11,
#   'low': 417.66,
#   'close': 421.03,
#   'volume': 20721500.0,
#   'adj_high': 421.11,
#   'adj_low': 417.66,
#   'adj_close': 421.03,
#   'adj_open': 419.8,
#   'adj_volume': 20752144.0,
#   'split_factor': 1.0,
#   'dividend': 0.75,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-15T00:00:00+0000'},
#  {'open': 414.8,
#   'high': 417.72,
#   'low': 412.45,
#   'close': 416.86,
#   'volume': 18250400.0,
#   'adj_high': 417.72,
#   'adj_low': 412.4456,
#   'adj_close': 416.11,
#   'adj_open': 414.8,
#   'adj_volume': 18266980.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-14T00:00:00+0000'},
#  {'open': 410.08,
#   'high': 414.95,
#   'low': 409.58,
#   'close': 414.01,
#   'volume': 18533284.0,
#   'adj_high': 414.95,
#   'adj_low': 409.57,
#   'adj_close': 414.01,
#   'adj_open': 409.59,
#   'adj_volume': 19414271.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-13T00:00:00+0000'},
#  {'open': 407.06,
#   'high': 408.76,
#   'low': 404.24,
#   'close': 406.81,
#   'volume': 16739400.0,
#   'adj_high': 408.76,
#   'adj_low': 404.2434,
#   'adj_close': 406.81,
#   'adj_open': 407.06,
#   'adj_volume': 16762883.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-12T00:00:00+0000'},
#  {'open': 404.03,
#   'high': 408.05,
#   'low': 402.26,
#   'close': 406.02,
#   'volume': 19018300.0,
#   'adj_high': 408.05,
#   'adj_low': 402.2624,
#   'adj_close': 406.02,
#   'adj_open': 404.03,
#   'adj_volume': 19276666.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-09T00:00:00+0000'},
#  {'open': 402.44,
#   'high': 405.86,
#   'low': 399.94,
#   'close': 402.69,
#   'volume': 18649900.0,
#   'adj_high': 405.86,
#   'adj_low': 399.9407,
#   'adj_close': 402.69,
#   'adj_open': 402.44,
#   'adj_volume': 20203030.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-08T00:00:00+0000'},
#  {'open': 408.635,
#   'high': 410.05,
#   'low': 397.47,
#   'close': 398.43,
#   'volume': 20244294.0,
#   'adj_high': 410.08,
#   'adj_low': 397.47,
#   'adj_close': 398.43,
#   'adj_open': 408.635,
#   'adj_volume': 20650906.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-07T00:00:00+0000'},
#  {'open': 400.235,
#   'high': 405.67,
#   'low': 398.505,
#   'close': 399.61,
#   'volume': 24826640.0,
#   'adj_high': 405.67,
#   'adj_low': 398.5,
#   'adj_close': 399.61,
#   'adj_open': 400.0,
#   'adj_volume': 24946525.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-06T00:00:00+0000'},
#  {'open': 389.17,
#   'high': 401.04,
#   'low': 385.58,
#   'close': 395.15,
#   'volume': 40652000.0,
#   'adj_high': 401.04,
#   'adj_low': 385.58,
#   'adj_close': 395.15,
#   'adj_open': 389.17,
#   'adj_volume': 40709238.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-05T00:00:00+0000'},
#  {'open': 412.49,
#   'high': 415.0,
#   'low': 404.34,
#   'close': 408.49,
#   'volume': 29399700.0,
#   'adj_high': 415.0,
#   'adj_low': 404.34,
#   'adj_close': 408.49,
#   'adj_open': 412.49,
#   'adj_volume': 29437900.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-02T00:00:00+0000'},
#  {'open': 420.79,
#   'high': 427.46,
#   'low': 413.09,
#   'close': 417.11,
#   'volume': 30229100.0,
#   'adj_high': 427.46,
#   'adj_low': 413.0901,
#   'adj_close': 417.11,
#   'adj_open': 420.785,
#   'adj_volume': 30296400.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-08-01T00:00:00+0000'},
#  {'open': 420.5,
#   'high': 421.78,
#   'low': 412.21,
#   'close': 418.35,
#   'volume': 42806400.0,
#   'adj_high': 421.775,
#   'adj_low': 412.21,
#   'adj_close': 418.35,
#   'adj_open': 420.495,
#   'adj_volume': 42891366.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-31T00:00:00+0000'},
#  {'open': 427.72,
#   'high': 429.05,
#   'low': 417.36,
#   'close': 422.92,
#   'volume': 31694300.0,
#   'adj_high': 429.05,
#   'adj_low': 417.36,
#   'adj_close': 422.92,
#   'adj_open': 427.72,
#   'adj_volume': 32687578.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-30T00:00:00+0000'},
#  {'open': 431.58,
#   'high': 432.15,
#   'low': 424.7,
#   'close': 426.73,
#   'volume': 15021300.0,
#   'adj_high': 432.15,
#   'adj_low': 424.7042,
#   'adj_close': 426.73,
#   'adj_open': 431.58,
#   'adj_volume': 15125836.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-29T00:00:00+0000'},
#  {'open': 418.2,
#   'high': 428.92,
#   'low': 417.27,
#   'close': 425.27,
#   'volume': 23566500.0,
#   'adj_high': 428.915,
#   'adj_low': 417.27,
#   'adj_close': 425.27,
#   'adj_open': 418.2,
#   'adj_volume': 23583839.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-26T00:00:00+0000'},
#  {'open': 428.8,
#   'high': 429.8,
#   'low': 417.51,
#   'close': 418.4,
#   'volume': 29904800.0,
#   'adj_high': 429.8,
#   'adj_low': 417.51,
#   'adj_close': 418.4,
#   'adj_open': 428.8,
#   'adj_volume': 29943795.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-25T00:00:00+0000'},
#  {'open': 440.45,
#   'high': 441.48,
#   'low': 427.59,
#   'close': 428.9,
#   'volume': 26761700.0,
#   'adj_high': 441.48,
#   'adj_low': 427.585,
#   'adj_close': 428.9,
#   'adj_open': 440.45,
#   'adj_volume': 26805800.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-24T00:00:00+0000'},
#  {'open': 443.9,
#   'high': 448.39,
#   'low': 443.1,
#   'close': 444.85,
#   'volume': 13075000.0,
#   'adj_high': 448.39,
#   'adj_low': 443.1,
#   'adj_close': 444.85,
#   'adj_open': 443.895,
#   'adj_volume': 13107050.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-23T00:00:00+0000'},
#  {'open': 441.79,
#   'high': 444.6,
#   'low': 438.91,
#   'close': 442.94,
#   'volume': 15784700.0,
#   'adj_high': 444.6,
#   'adj_low': 438.9125,
#   'adj_close': 442.94,
#   'adj_open': 441.79,
#   'adj_volume': 15808755.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-22T00:00:00+0000'},
#  {'open': 433.1,
#   'high': 441.14,
#   'low': 432.0,
#   'close': 437.11,
#   'volume': 20862400.0,
#   'adj_high': 441.14,
#   'adj_low': 432.0,
#   'adj_close': 437.11,
#   'adj_open': 433.1,
#   'adj_volume': 20940417.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-19T00:00:00+0000'},
#  {'open': 444.34,
#   'high': 444.65,
#   'low': 434.4,
#   'close': 440.37,
#   'volume': 20724014.0,
#   'adj_high': 444.65,
#   'adj_low': 434.4,
#   'adj_close': 440.37,
#   'adj_open': 444.34,
#   'adj_volume': 20794822.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-18T00:00:00+0000'},
#  {'open': 442.43,
#   'high': 444.85,
#   'low': 439.18,
#   'close': 443.52,
#   'volume': 21741478.0,
#   'adj_high': 444.85,
#   'adj_low': 439.18,
#   'adj_close': 443.52,
#   'adj_open': 442.59,
#   'adj_volume': 21754021.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-17T00:00:00+0000'},
#  {'open': 454.22,
#   'high': 454.3,
#   'low': 446.66,
#   'close': 449.52,
#   'volume': 17038389.0,
#   'adj_high': 454.3,
#   'adj_low': 446.66,
#   'adj_close': 449.52,
#   'adj_open': 454.22,
#   'adj_volume': 17175679.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-16T00:00:00+0000'},
#  {'open': 453.42,
#   'high': 457.26,
#   'low': 451.43,
#   'close': 453.96,
#   'volume': 13621481.0,
#   'adj_high': 457.26,
#   'adj_low': 451.43,
#   'adj_close': 453.96,
#   'adj_open': 453.3,
#   'adj_volume': 14429447.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-15T00:00:00+0000'},
#  {'open': 454.33,
#   'high': 456.36,
#   'low': 450.65,
#   'close': 453.55,
#   'volume': 16311300.0,
#   'adj_high': 456.36,
#   'adj_low': 450.645,
#   'adj_close': 453.55,
#   'adj_open': 454.325,
#   'adj_volume': 16324274.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-12T00:00:00+0000'},
#  {'open': 462.73,
#   'high': 464.78,
#   'low': 451.55,
#   'close': 454.7,
#   'volume': 22835138.0,
#   'adj_high': 464.78,
#   'adj_low': 451.55,
#   'adj_close': 454.7,
#   'adj_open': 462.98,
#   'adj_volume': 23111175.0,
#   'split_factor': 1.0,
#   'dividend': 0.0,
#   'symbol': 'MSFT',
#   'exchange': 'XNAS',
#   'date': '2024-07-11T00:00:00+0000'}]

# %%
df = pd.json_normalize(historical_data, meta=['date'])
df
# Out:
#        open      high     low   close      volume  adj_high  adj_low  \
# 0   420.090  424.8800  417.80  423.46  16271900.0  424.8800  417.800
# 1   425.105  427.2299  422.02  422.99  18332444.0  427.2299  422.020
# 2   419.590  429.0400  418.85  427.99  23439600.0  429.0414  418.850
# 3   418.380  421.0800  414.85  418.79  27651300.0  421.0800  414.850
# 4   411.370  417.4000  411.06  417.00  24802100.0  417.4000  411.060
# ..      ...       ...     ...     ...         ...       ...      ...
# 95  442.430  444.8500  439.18  443.52  21741478.0  444.8500  439.180
# 96  454.220  454.3000  446.66  449.52  17038389.0  454.3000  446.660
# 97  453.420  457.2600  451.43  453.96  13621481.0  457.2600  451.430
# 98  454.330  456.3600  450.65  453.55  16311300.0  456.3600  450.645
# 99  462.730  464.7800  451.55  454.70  22835138.0  464.7800  451.550
#
#     adj_close  adj_open  adj_volume  split_factor  dividend symbol exchange  \
# 0      423.46   420.090  16271921.0           1.0       0.0   MSFT     XNAS
# 1      422.99   425.105  18332444.0           1.0       0.0   MSFT     XNAS
# 2      427.99   419.585  23458889.0           1.0       0.0   MSFT     XNAS
# 3      418.79   418.380  27691090.0           1.0       0.0   MSFT     XNAS
# 4      417.00   411.365  24814626.0           1.0       0.0   MSFT     XNAS
# ..        ...       ...         ...           ...       ...    ...      ...
# 95     443.52   442.590  21754021.0           1.0       0.0   MSFT     XNAS
# 96     449.52   454.220  17175679.0           1.0       0.0   MSFT     XNAS
# 97     453.96   453.300  14429447.0           1.0       0.0   MSFT     XNAS
# 98     453.55   454.325  16324274.0           1.0       0.0   MSFT     XNAS
# 99     454.70   462.980  23111175.0           1.0       0.0   MSFT     XNAS
#
#                         date
# 0   2024-11-29T00:00:00+0000
# 1   2024-11-27T00:00:00+0000
# 2   2024-11-26T00:00:00+0000
# 3   2024-11-25T00:00:00+0000
# 4   2024-11-22T00:00:00+0000
# ..                       ...
# 95  2024-07-17T00:00:00+0000
# 96  2024-07-16T00:00:00+0000
# 97  2024-07-15T00:00:00+0000
# 98  2024-07-12T00:00:00+0000
# 99  2024-07-11T00:00:00+0000
#
# [100 rows x 15 columns]

# %%
def shorten_date(date):
    return date[0:10]

df['date']
df['short_date'] = df['date'].apply(shorten_date)
df
# Out:
#        open      high     low   close      volume  adj_high  adj_low  \
# 0   420.090  424.8800  417.80  423.46  16271900.0  424.8800  417.800
# 1   425.105  427.2299  422.02  422.99  18332444.0  427.2299  422.020
# 2   419.590  429.0400  418.85  427.99  23439600.0  429.0414  418.850
# 3   418.380  421.0800  414.85  418.79  27651300.0  421.0800  414.850
# 4   411.370  417.4000  411.06  417.00  24802100.0  417.4000  411.060
# ..      ...       ...     ...     ...         ...       ...      ...
# 95  442.430  444.8500  439.18  443.52  21741478.0  444.8500  439.180
# 96  454.220  454.3000  446.66  449.52  17038389.0  454.3000  446.660
# 97  453.420  457.2600  451.43  453.96  13621481.0  457.2600  451.430
# 98  454.330  456.3600  450.65  453.55  16311300.0  456.3600  450.645
# 99  462.730  464.7800  451.55  454.70  22835138.0  464.7800  451.550
#
#     adj_close  adj_open  adj_volume  split_factor  dividend symbol exchange  \
# 0      423.46   420.090  16271921.0           1.0       0.0   MSFT     XNAS
# 1      422.99   425.105  18332444.0           1.0       0.0   MSFT     XNAS
# 2      427.99   419.585  23458889.0           1.0       0.0   MSFT     XNAS
# 3      418.79   418.380  27691090.0           1.0       0.0   MSFT     XNAS
# 4      417.00   411.365  24814626.0           1.0       0.0   MSFT     XNAS
# ..        ...       ...         ...           ...       ...    ...      ...
# 95     443.52   442.590  21754021.0           1.0       0.0   MSFT     XNAS
# 96     449.52   454.220  17175679.0           1.0       0.0   MSFT     XNAS
# 97     453.96   453.300  14429447.0           1.0       0.0   MSFT     XNAS
# 98     453.55   454.325  16324274.0           1.0       0.0   MSFT     XNAS
# 99     454.70   462.980  23111175.0           1.0       0.0   MSFT     XNAS
#
#                         date  short_date
# 0   2024-11-29T00:00:00+0000  2024-11-29
# 1   2024-11-27T00:00:00+0000  2024-11-27
# 2   2024-11-26T00:00:00+0000  2024-11-26
# 3   2024-11-25T00:00:00+0000  2024-11-25
# 4   2024-11-22T00:00:00+0000  2024-11-22
# ..                       ...         ...
# 95  2024-07-17T00:00:00+0000  2024-07-17
# 96  2024-07-16T00:00:00+0000  2024-07-16
# 97  2024-07-15T00:00:00+0000  2024-07-15
# 98  2024-07-12T00:00:00+0000  2024-07-12
# 99  2024-07-11T00:00:00+0000  2024-07-11
#
# [100 rows x 16 columns]

# %%
df.plot.line('short_date', y=['adj_high', 'adj_close'])
plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Adjusted Price (USD)')
plt.title('Microsoft EOD Data')

# plt.legend(title='')
plt.legend(labels=['Adjusted High Price', 'Adjusted Closing Price'])

# %%
df.plot.line('short_date', 'volume')
plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Microsoft EOD Data')

# plt.legend(title='')
plt.legend(labels=['Volume'])

# %% [markdown]
# numbers:
#     highest volume
#     lowest volume
#     highest price
#     lowest price
#
# over time:
#     closing versus opening
#     volume
#
# averages (over different periods):
#     volume
#     high
#     low
#     closing
# last week
# last month

# %%
df['volume'].max()
# Out:
# 55155300.0

# %%
df[['volume', 'short_date']].sort_values('volume', ascending=False)
# Out:
#         volume  short_date
# 49  55155300.0  2024-09-20
# 20  53473867.0  2024-10-31
# 85  42806400.0  2024-07-31
# 82  40652000.0  2024-08-05
# 86  31694300.0  2024-07-30
# ..         ...         ...
# 40  13460138.0  2024-10-03
# 46  13335000.0  2024-09-25
# 28  13284766.0  2024-10-21
# 67  13134700.0  2024-08-26
# 91  13075000.0  2024-07-23
#
# [100 rows x 2 columns]

# %%
df[['volume', 'short_date']].sort_values('volume', ascending=True).head(1)
# Out:
#         volume  short_date
# 91  13075000.0  2024-07-23

# %%
df[['adj_high', 'short_date']].sort_values('adj_high', ascending=False)
# Out:
#     adj_high  short_date
# 99    464.78  2024-07-11
# 97    457.26  2024-07-15
# 98    456.36  2024-07-12
# 96    454.30  2024-07-16
# 91    448.39  2024-07-23
# ..       ...         ...
# 58    408.65  2024-09-09
# 78    408.05  2024-08-09
# 79    405.86  2024-08-08
# 81    405.67  2024-08-06
# 82    401.04  2024-08-05
#
# [100 rows x 2 columns]

# %%
df[['adj_high', 'short_date']].sort_values('adj_high', ascending=True).head(1)
# Out:
#     adj_high  short_date
# 82    401.04  2024-08-05

# %%
df.plot.line('short_date', y=['adj_open', 'adj_close'])
plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Adjusted Price (USD)')
plt.title('Microsoft EOD Data')
plt.legend(labels=['Adjusted Opening Price', 'Adjusted Closing Price'])

# %%
df['volume'].mean()
# Out:
# 20284888.0

# %%
df['adj_high'].mean()
# Out:
# 425.37820500000015

# %%
df['adj_low'].mean()
# Out:
# 417.9611310000001

# %%
df['adj_close'].mean()
# Out:
# 421.5292
